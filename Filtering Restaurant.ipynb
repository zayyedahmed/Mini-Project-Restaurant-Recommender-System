# %%
import numpy as np 
import pandas as pd 
import json

# %%
def init_ds(json):
    ds= {}
    keys = json.keys()
    for k in keys:
        ds[k]= []
    return ds, keys

def read_json(file):
    dataset = {}
    keys = []
    with open(file, encoding='utf8') as file_lines:
        for count, line in enumerate(file_lines):
            data = json.loads(line.strip())
            if count ==0:
                dataset, keys = init_ds(data)
            for k in keys:
                dataset[k].append(data[k])
                
        return pd.DataFrame(dataset)

# %%
business = read_json('D:\Project\yelp_academic_dataset_business.json')

# %%
business.head()
# Out:
#               business_id                      name  \
# 0  f9NumwFMBDn751xgFiRbNA  The Range At Lake Norman
# 1  Yzvjg0SayhoZgCljUJRF9Q         Carlos Santo, NMD
# 2  XNoUzKckATkOD1hP6vghZg                   Felinus
# 3  6OAZjbxqM5ol29BuHsil3w      Nevada House of Hose
# 4  51M2Kk903DFYI6gnB5I6SQ   USE MY GUY SERVICES LLC
#
#                      address             city state postal_code   latitude  \
# 0            10913 Bailey Rd        Cornelius    NC       28031  35.462724
# 1  8880 E Via Linda, Ste 107       Scottsdale    AZ       85258  33.569404
# 2      3554 Rue Notre-Dame O         Montreal    QC     H4C 1P4  45.479984
# 3             1015 Sharp Cir  North Las Vegas    NV       89030  36.219728
# 4         4827 E Downing Cir             Mesa    AZ       85205  33.428065
#
#     longitude  stars  review_count  is_open  \
# 0  -80.852612    3.5            36        1
# 1 -111.890264    5.0             4        1
# 2  -73.580070    5.0             5        1
# ...

# %%
business.dropna(inplace=True)

# %%
business.isna().sum()
# Out:
# business_id     0
# name            0
# address         0
# city            0
# state           0
# postal_code     0
# latitude        0
# longitude       0
# stars           0
# review_count    0
# is_open         0
# attributes      0
# categories      0
# hours           0
# dtype: int64

# %%
business = business[business['categories'].str.contains("Restaurants")]

# %%
business
# Out:
#                    business_id                             name  \
# 8       pQeaRpvuhoEqudo3uymHIQ              The Empanadas House
# 24      eBEfgOPG7pvFhb2wcG9I7w                  Philthy Phillys
# 30      9sRGfSVEfLhN_km60YruTA               Apadana Restaurant
# 33      vjTVxnsQEZ34XjYNS-XUpA                Wetzel's Pretzels
# 41      98hyK2QEUeI8v2y0AghfZA  Pho Lee's Vietnamese Restaurant
# ...                        ...                              ...
# 209381  xVpE01l6ZXdEtVf5PkRpDg                            Julep
# 209383  BAVuLTDmpSzDCk37A5HjtQ                Bruegger's Bagels
# 209385  hskVqZCPqy-omm9CHi44xQ                         Domino's
# 209388  9Q0fPWAjUweoFDk0kafuzQ                      Nishi Sushi
# 209390  SYa2j1boLF8DcGVOYfHPcA                        Five Guys
#
#                                  address           city state postal_code  \
# 8                         404 E Green St      Champaign    IL       61820
# ...

# %%
business[business['state']=="NV"]
# Out:
#                    business_id                                      name  \
# 42      fhNf_sg-XzZ3e7HEVGuOZg                     Meat Chix And Wieners
# 86      OWkS1FXNJbozn-qPg3LWxg                         Mama Napoli Pizza
# 130     Q_dh08clYUPj13GmCRzIVA        Kulinarya Express Filipino Kitchen
# 157     Yr_w9lakJrKMyEG_hI6zbA                   Fat Moe's Pizza & Wings
# 238     AN0bWhisCf6LN9eHZ7DQ3w                     Los Olivos Ristorante
# ...                        ...                                       ...
# 209273  Q2pyp7Nb3cD4Br2BOnxUDA                            Greek Delights
# 209317  tv-WIUQifcp5J9pUKoiE3Q                             Dragon Grille
# 209334  7V82ANZ7_ARkA7o0pAMAlA                               Galaxy Cafe
# 209367  aJK0MWXKgXIgQUCM9fqSJQ  The Original Graziano's Pizza Restaurant
# 209369  5VXlHFrYZZzj7zfZEsz5nQ                         Dragon Noodle Co.
#
#                                address       city state postal_code  \
# ...

# %%
NV = business[business['state']=="NV"]

# %%
NV.to_csv('D:\\Project\\Restaurant_NV.csv', index=False)

# %%
NV.head()
# Out:
#                 business_id                                name  \
# 42   fhNf_sg-XzZ3e7HEVGuOZg               Meat Chix And Wieners
# 86   OWkS1FXNJbozn-qPg3LWxg                   Mama Napoli Pizza
# 130  Q_dh08clYUPj13GmCRzIVA  Kulinarya Express Filipino Kitchen
# 157  Yr_w9lakJrKMyEG_hI6zbA             Fat Moe's Pizza & Wings
# 238  AN0bWhisCf6LN9eHZ7DQ3w               Los Olivos Ristorante
#
#                             address       city state postal_code   latitude  \
# 42              6530 S Decatur Blvd  Las Vegas    NV       89118  36.071196
# 86                                   Las Vegas    NV       89109  36.128561
# 130  7960 S Rainbow Blvd, Ste 8000A  Las Vegas    NV       89139  36.043663
# 157     6125 W Tropicana Ave, Ste F  Las Vegas    NV       89103  36.099361
# 238            3759 E Desert Inn Rd  Las Vegas    NV       89121  36.129178
#
#       longitude  stars  review_count  is_open  \
# 42  -115.207463    3.0            10        0
# ...

# %%
NV = NV[NV['categories'].str.contains("Halal")]

# %%
NV.to_csv('D:\\Project\\Restaurant_Halal_NV.csv', index=False)

# %%
business.to_csv('D:\\Project\\Restaurant.csv', index=False)

# %%
business = business[business['categories'].str.contains("Halal")]

# %%
business.head()
# Out:
#                  business_id                        name  \
# 82    RrapAhd8ZxCj-iue7fu9FA            Ganga Restaurant
# 288   ebwM2pckHieHvK6h1scuBw  Lazeez Mediterranean Grill
# 812   QHRF1RvAmZIbnXWK_fCPcQ                   Pita Land
# 996   9j4nk2WOT6XCDRgX-lGzVA              Fritou Chicken
# 1175  eRZuxjnaMviiVyvhejwTBQ              Afghan Cuisine
#
#                            address           city state postal_code  \
# 82               515 4th Avenue SW        Calgary    AB     T2P 0J8
# 288              9311 Jw Clay Blvd      Charlotte    NC       28262
# 812   30 Eglinton Ave W, Unit #12B    Mississauga    ON     L5R 3E7
# 996     3-1110 Canterbury Drive SW        Calgary    AB     T2W 3P5
# 1175   10909 Yonge Street, Unit 52  Richmond Hill    ON     L4C 4M6
#
#        latitude   longitude  stars  review_count  is_open  \
# 82    51.049407 -114.072656    1.5             3        1
# 288   35.311397  -80.746334    3.5           124        0
# ...

# %%
business.to_csv('D:\\Project\\Restaurant_Halal.csv', index=False)
