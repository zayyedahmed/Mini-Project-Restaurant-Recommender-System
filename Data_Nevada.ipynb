# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('D:\\Project\\Data NV.csv')

# %%
data.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  xQY8N_XvtGbearJ5X4QryQ  OwjRMXRC0KyPrIlcjaXeFQ  -MhfebM0QIsKt87iDN-FNw
# 1  i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ  5JxlZaqCnk1MnbgRirs40Q
# 2  6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg  IS4cv902ykd8wj1TR0N3-A
# 3  L2O_INwlrRuoX05KSjc4eg  5vD2kmE25YBrbayKhykNxQ  nlxHRv1zXGT0c0K51q3jDg
# 4  lpFIJYpsvDxyph-kPzZ6aA  dsd-KNYKMpx6ma_sRWCSkQ  FNCJpSn0tL9iqoY3JC73qw
#
#    stars_x  useful  funny  cool  \
# 0      2.0       5      0     0
# 1      1.0       0      0     0
# 2      4.0       0      0     0
# 3      5.0       2      0     0
# 4      5.0       0      0     0
#
#                                                 text                 date  \
# 0  As someone who has worked with many museums, I...  2015-04-15 05:21:16
# 1  Dismal, lukewarm, defrosted-tasting "TexMex" g...  2011-05-27 05:30:52
# 2  Oh happy day, finally have a Canes near my cas...  2017-01-14 21:56:57
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2802658 entries, 0 to 2802657
# Data columns (total 17 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   review_id    object
#  1   user_id      object
#  2   business_id  object
#  3   stars_x      float64
#  4   useful       int64
#  5   funny        int64
#  6   cool         int64
#  7   text         object
#  8   date         object
#  9   name         object
#  10  city         object
#  11  state        object
#  12  address      object
#  13  longitude    float64
#  14  latitude     float64
#  15  stars_y      float64
#  16  categories   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 363.5+ MB

# %%
data.isna().sum()
# Out:
# review_id          0
# user_id            0
# business_id        0
# stars_x            0
# useful             0
# funny              0
# cool               0
# text               2
# date               0
# name               0
# city               0
# state              0
# address        47109
# longitude          0
# latitude           0
# stars_y            0
# categories       423
# dtype: int64

# %%
data = data.drop(['address','stars_x', 'useful', 'funny', 'cool', 'date'], axis=1)

# %%
data.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  xQY8N_XvtGbearJ5X4QryQ  OwjRMXRC0KyPrIlcjaXeFQ  -MhfebM0QIsKt87iDN-FNw
# 1  i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ  5JxlZaqCnk1MnbgRirs40Q
# 2  6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg  IS4cv902ykd8wj1TR0N3-A
# 3  L2O_INwlrRuoX05KSjc4eg  5vD2kmE25YBrbayKhykNxQ  nlxHRv1zXGT0c0K51q3jDg
# 4  lpFIJYpsvDxyph-kPzZ6aA  dsd-KNYKMpx6ma_sRWCSkQ  FNCJpSn0tL9iqoY3JC73qw
#
#                                                 text  \
# 0  As someone who has worked with many museums, I...
# 1  Dismal, lukewarm, defrosted-tasting "TexMex" g...
# 2  Oh happy day, finally have a Canes near my cas...
# 3  This is definitely my favorite fast food sub s...
# 4  Awesome office and staff, very professional an...
#
#                                    name       city state   longitude  \
# 0          Bellagio Gallery of Fine Art  Las Vegas    NV -115.177637
# ...

# %%
data.isna().sum()
# Out:
# review_id        0
# user_id          0
# business_id      0
# text             2
# name             0
# city             0
# state            0
# longitude        0
# latitude         0
# stars_y          0
# categories     423
# dtype: int64

# %%
data['categories'].isna().sum()
# Out:
# 423

# %%
len(data['categories'])
# Out:
# 2802658

# %%
Nan = (423/2802658)*100 #persentase data yang NAN
print("Presentase Data yang NaN Adalah: ", np.round(Nan, 3),'%')
# Out:
# Presentase Data yang NaN Adalah:  0.015 %

# %%
non = (2802235/2802658)*100 #Presentase data yang Non NaN
print("Presentase Data yang Tidak NaN Adalah: ", np.round(non, 3),'%')
# Out:
# Presentase Data yang Tidak NaN Adalah:  99.985 %

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# review_id      0
# user_id        0
# business_id    0
# text           0
# name           0
# city           0
# state          0
# longitude      0
# latitude       0
# stars_y        0
# categories     0
# dtype: int64

# %%
data['state'].unique()
# Out:
# array(['NV'], dtype=object)

# %%
data['city'].unique()
# Out:
# array(['Las Vegas', 'Henderson', 'North Las Vegas', 'Boulder City',
#        'Blue Diamond', 'Enterprise', 'Las  Vegas', 'Vegas', 'N Las Vegas',
#        'LAS VEGAS', 'las vegas', 'Green Valley', '110 Las Vegas',
#        'Paradise', 'N. Las Vegas', 'Las vegas', 'West Las Vegas',
#        'HENDERSON', 'Clark', 'Lake Mead', 'Nellis AFB', 'Whitney',
#        'Nellis Air Force Base', 'South Las Vegas', 'City Center',
#        'henderson', 'Nellis Afb', 'Decatur', 'North Las Vegas ',
#        'Sunrise Manor', 'Reno', 'Hendserson', 'La Vegas', 'Spring Valley',
#        'LAS VEGAS AP', 'W Spring Valley', 'Sunrise', 'las Vegas',
#        'Las Vegas ', 'W Henderson', 'Summerlin', 'Hnederson',
#        'Las Vegas, NV', 'N E Las Vegas', 'San Antonio', 'Henderston',
#        'Las Vegass', 'Centennial Hills', 'NELLIS AFB', 'Redding',
#        'C Las Vegas', 'N W Las Vegas', 'Black Rock City', 'Seven Hills',
#        'Las Vegas,', 'Summerlin South', 'Las Vegas Nevada', 'Jean',
# ...

# %%
data['city'] = data['city'].replace(
    ('Las  Vegas', 'LAS VEGAS', 'Las Vegas, Nevada', 'Las Vegas Nevada', '110 Las Vegas', 'Las vegas', 'La Vegas', 'Las Vegas NV', 'Las Vegass'),
    'Las Vegas'
)
data['city'] = data['city'].replace(
    ('N Las Vegas', 'N. Las Vegas', 'N.Las Vegas'),
    'North Las Vegas'
)
data['city'] = data['city'].replace(
    ('Nellis AFB', 'NELLIS AIR FORCE BASE', "NELLIS AFB"),
    'Nellis Air Force Base'
)

# %%
b = list(filter(lambda a : "Restaurant" in a, data["categories"]))
b
# Out:
# ['Restaurants, Mexican',
#  'Fast Food, Restaurants, Sandwiches, Chicken Wings',
#  'Restaurants, Delis, Sandwiches, Fast Food',
#  'Mexican, Restaurants',
#  'Mexican, Restaurants',
#  'Southern, Mexican, New Mexican Cuisine, Spanish, Tex-Mex, Barbeque, Restaurants, American (Traditional), American (New)',
#  'Restaurants, Sushi Bars, Japanese',
#  'Restaurants, Sandwiches, Fast Food',
#  'Casinos, Nightlife, Restaurants, Hotels & Travel, Tennis, Active Life, Steakhouses, Event Planning & Services, Music Venues, Sushi Bars, Arts & Entertainment, Food, Japanese, Hotels',
#  'Restaurants, Mexican, Fast Food',
#  'Asian Fusion, Event Planning & Services, Restaurants, Buffets, Sushi Bars, Hotels & Travel, Hotels, Breakfast & Brunch, American (Traditional)',
#  'Restaurants, Food, Cafes, Tea Rooms, Bubble Tea, Desserts',
#  'Breakfast & Brunch, Nightlife, Bars, American (New), Restaurants, Sports Bars, American (Traditional), Food, Beer, Wine & Spirits',
# ...

# %%
c = list(filter(lambda a : "Indian" in a, data['categories']))
c
# Out:
# ['Restaurants, Arabian, Halal, Pakistani, Indian',
#  'Middle Eastern, Indian, Vegetarian, Restaurants',
#  'Middle Eastern, Indian, Vegetarian, Restaurants',
#  'Restaurants, Arabian, Halal, Pakistani, Indian',
#  'Pakistani, Restaurants, Indian',
#  'Restaurants, Arabian, Halal, Pakistani, Indian',
#  'Restaurants, Arabian, Halal, Pakistani, Indian',
#  'Restaurants, Pakistani, Pizza, Indian, Asian Fusion, Soul Food',
#  'Pakistani, Restaurants, Indian',
#  'Event Planning & Services, Caterers, Pakistani, Vegetarian, Indian, Vegan, Restaurants',
#  'Restaurants, Arabian, Halal, Pakistani, Indian',
#  'Restaurants, Arabian, Halal, Pakistani, Indian',
#  'Middle Eastern, Indian, Vegetarian, Restaurants',
#  'Pakistani, Restaurants, Indian',
#  'Pakistani, Restaurants, Indian',
#  'Restaurants, Arabian, Halal, Pakistani, Indian',
#  'Middle Eastern, Indian, Vegetarian, Restaurants',
#  'Restaurants, Arabian, Halal, Pakistani, Indian',
# ...

# %%
data[data['categories'].str.contains("Restaurant")]
# Out:
#                       review_id                 user_id  \
# 1        i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ
# 2        6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg
# 3        L2O_INwlrRuoX05KSjc4eg  5vD2kmE25YBrbayKhykNxQ
# 8        bVTjZgRNq8ToxzvtiVrqMA  2hRe26HSCAWbFRn5WChK-Q
# 10       TeX0eOIeZb_wpo86rCedXQ  RR-2nouBn408e3djxC470g
# ...                         ...                     ...
# 2802650  T34JvlaKD1qcQARVOOHm4w  7puz3FPymI83yvk1_J7ilQ
# 2802652  SkiPC10TBymnU-y8ScdQ_w  23cjtl3AWJtxKL3O78-Djw
# 2802653  cPX3OKqbv3-9ZYZTp_UKyA  bH3Uc0YNlnKubj8cT4nQ0w
# 2802656  EcY_p50zPIQ2R6rf6-5CjA  Scmyz7MK4TbXXYcaLZxIxQ
# 2802657  nK0JGgr8aO4mcFPU4pDOEA  fiA6ztHPONUkmX6yKIXyHg
#
#                     business_id  \
# 1        5JxlZaqCnk1MnbgRirs40Q
# 2        IS4cv902ykd8wj1TR0N3-A
# 3        nlxHRv1zXGT0c0K51q3jDg
# 8        d4qwVw4PcN-_2mK2o1Ro1g
# 10       d4qwVw4PcN-_2mK2o1Ro1g
# ...                         ...
# 2802650  AUOlDSQ8R2wIkN4lQ4kVDg
# ...

# %%
len(data[data['categories'].str.contains("Restaurant")])
# Out:
# 1688726

# %%
len(data[data['categories'].str.contains("Halal")])
# Out:
# 12024

# %%
res_halal = data[data['categories'].str.contains("Halal")]

# %%
res_halal
# Out:
#                       review_id                 user_id  \
# 163      kCkyGrMMRQbqx69dgzmnEA  I143qmTjREqTwAVWVsB6sw
# 854      JJUHx7FNoWnBYsIbEoBopw  GOGAWajma1T-dPZn8xls6A
# 1141     4wUnRF4-DistlPJnUwU-Uw  X40NV4DapcQBiYiPMwQkOw
# 1278     L94lNIuNw3G1UaXgxAgTWg  sPr42M6_rRkKJXNepmfm1A
# 1692     SGaOzRxoEuiGBdSCWUJ8fQ  ykmEwulkVsiEesovrrpVSA
# ...                         ...                     ...
# 2802022  gjkwH-L4mbN4hH322VXDCA  odr45NPHmrhFDOenFSjYog
# 2802050  qOZdLhil401s-fRt77lnMQ  mCwoTG5cOLKlb9n_t30UYA
# 2802368  KO4M7wWVohTz2pzxVTvTDw  NHiZXgMVz6d7kuu8hbMSxg
# 2802570  nrhjUcQba0EefGbePFKOMg  XPV9T5EEthLXyZVRtSlEXw
# 2802618  n_ZcSVfiKlWLrfmG41s65A  tzvSwlqFkBsZms7LGmzL4Q
#
#                     business_id  \
# 163      EfAqol3tWckyNrBMIooJmg
# 854      EfAqol3tWckyNrBMIooJmg
# 1141     EfAqol3tWckyNrBMIooJmg
# 1278     EfAqol3tWckyNrBMIooJmg
# 1692     EfAqol3tWckyNrBMIooJmg
# ...                         ...
# 2802022  Ssa6XY_RdDRRB9wuVIeIWw
# ...

# %%
res_halal['categories'].unique()
# Out:
# array(['Restaurants, Arabian, Halal, Pakistani, Indian',
#        'Restaurants, Persian/Iranian, Halal, Mediterranean',
#        'Restaurants, Falafel, Mediterranean, Middle Eastern, Halal',
#        'Pakistani, Gluten-Free, Indian, Nightlife, Halal, Restaurants, Bars',
#        'Indian, Halal, Mediterranean, Restaurants',
#        'Beer, Wine & Spirits, Indian, Restaurants, Specialty Food, Ethnic Food, Halal, Food, Seafood, Vegan, Nightlife, Bars, Desserts, Buffets',
#        'Mediterranean, Food, Cafes, Restaurants, Coffee & Tea, Burgers, Gluten-Free, Halal, Sandwiches, Vegetarian',
#        'Pakistani, Restaurants, Himalayan/Nepalese, Indian, Vegan, Halal, Vegetarian',
#        'Persian/Iranian, Restaurants, Sandwiches, Pizza, Mediterranean, Bakeries, Halal, Food',
#        'Burgers, Restaurants, Fast Food, Chicken Wings, Halal',
#        'Pakistani, Halal, Himalayan/Nepalese, Vegetarian, Indian, Vegan, Restaurants',
#        'Szechuan, Halal, Restaurants, Dim Sum, Chinese',
# ...

# %%
res_halal = res_halal.rename(columns={'stars_y':'rating'})

# %%
res_halal
# Out:
#                       review_id                 user_id  \
# 163      kCkyGrMMRQbqx69dgzmnEA  I143qmTjREqTwAVWVsB6sw
# 854      JJUHx7FNoWnBYsIbEoBopw  GOGAWajma1T-dPZn8xls6A
# 1141     4wUnRF4-DistlPJnUwU-Uw  X40NV4DapcQBiYiPMwQkOw
# 1278     L94lNIuNw3G1UaXgxAgTWg  sPr42M6_rRkKJXNepmfm1A
# 1692     SGaOzRxoEuiGBdSCWUJ8fQ  ykmEwulkVsiEesovrrpVSA
# ...                         ...                     ...
# 2802022  gjkwH-L4mbN4hH322VXDCA  odr45NPHmrhFDOenFSjYog
# 2802050  qOZdLhil401s-fRt77lnMQ  mCwoTG5cOLKlb9n_t30UYA
# 2802368  KO4M7wWVohTz2pzxVTvTDw  NHiZXgMVz6d7kuu8hbMSxg
# 2802570  nrhjUcQba0EefGbePFKOMg  XPV9T5EEthLXyZVRtSlEXw
# 2802618  n_ZcSVfiKlWLrfmG41s65A  tzvSwlqFkBsZms7LGmzL4Q
#
#                     business_id  \
# 163      EfAqol3tWckyNrBMIooJmg
# 854      EfAqol3tWckyNrBMIooJmg
# 1141     EfAqol3tWckyNrBMIooJmg
# 1278     EfAqol3tWckyNrBMIooJmg
# 1692     EfAqol3tWckyNrBMIooJmg
# ...                         ...
# 2802022  Ssa6XY_RdDRRB9wuVIeIWw
# ...

# %%
res_halal.to_csv('D:\\Project\\Res_Nev_Halal_Final.csv', index=False)

# %%
data.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  xQY8N_XvtGbearJ5X4QryQ  OwjRMXRC0KyPrIlcjaXeFQ  -MhfebM0QIsKt87iDN-FNw
# 1  i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ  5JxlZaqCnk1MnbgRirs40Q
# 2  6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg  IS4cv902ykd8wj1TR0N3-A
# 3  L2O_INwlrRuoX05KSjc4eg  5vD2kmE25YBrbayKhykNxQ  nlxHRv1zXGT0c0K51q3jDg
# 4  lpFIJYpsvDxyph-kPzZ6aA  dsd-KNYKMpx6ma_sRWCSkQ  FNCJpSn0tL9iqoY3JC73qw
#
#                                                 text  \
# 0  As someone who has worked with many museums, I...
# 1  Dismal, lukewarm, defrosted-tasting "TexMex" g...
# 2  Oh happy day, finally have a Canes near my cas...
# 3  This is definitely my favorite fast food sub s...
# 4  Awesome office and staff, very professional an...
#
#                                    name       city state   longitude  \
# 0          Bellagio Gallery of Fine Art  Las Vegas    NV -115.177637
# ...

# %%
res = data[data['categories'].str.contains("Restaurant")]

# %%
res.head()
# Out:
#                  review_id                 user_id             business_id  \
# 1   i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ  5JxlZaqCnk1MnbgRirs40Q
# 2   6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg  IS4cv902ykd8wj1TR0N3-A
# 3   L2O_INwlrRuoX05KSjc4eg  5vD2kmE25YBrbayKhykNxQ  nlxHRv1zXGT0c0K51q3jDg
# 8   bVTjZgRNq8ToxzvtiVrqMA  2hRe26HSCAWbFRn5WChK-Q  d4qwVw4PcN-_2mK2o1Ro1g
# 10  TeX0eOIeZb_wpo86rCedXQ  RR-2nouBn408e3djxC470g  d4qwVw4PcN-_2mK2o1Ro1g
#
#                                                  text  \
# 1   Dismal, lukewarm, defrosted-tasting "TexMex" g...
# 2   Oh happy day, finally have a Canes near my cas...
# 3   This is definitely my favorite fast food sub s...
# 8   10pm on a super bowl Sunday and they're alread...
# 10  Holy heck this place is amazing. I love their ...
#
#                               name       city state   longitude   latitude  \
# 1          Cabo Mexican Restaurant  Las Vegas    NV -115.338821  36.118343
# ...

# %%
res['city'].unique()
# Out:
# array(['Las Vegas', 'Henderson', 'North Las Vegas', 'Boulder City',
#        'Blue Diamond', 'Enterprise', 'Green Valley', 'Paradise',
#        'Nellis Air Force Base', 'Sunrise Manor', 'Spring Valley',
#        'San Antonio', 'Summerlin', 'Summerlin South', 'Pahrump',
#        '4321 W Flamingo Rd', 'South Las Vegas'], dtype=object)

# %%
res = res.rename(columns={'stars_y':'rating'})

# %%
res.to_csv('D:\\Project\\Restaurant_Nevada.csv', index=False)
